# %% [markdown]
# ## **Visualizzazione dei dati**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.arange(-10,11)

# %%
plt.figure(figsize = (12,6)) #dimesioni grafico
plt.title("Grafico") #titolo

plt.plot(x, x **2) #linee/dati
plt.plot(x, -1 * (x**2)) #linee/dati

# %%
plt.figure(figsize=(12,6))
plt.title("Grafico")

plt.subplot(1,2,1) # rows, columns, panel selected
plt.plot(x , x**2)
plt.plot([0, 0, 0], [-10, 0, 100])
plt.legend(["X^2", "Vertical Line"])
plt.xlabel("X")
plt.ylabel("X squared")


plt.subplot(1,2,2) # rows, columns, panel selected
plt.plot(x , -1 * (x**2))
plt.plot([-10, 0, 10], [-50, -50, -50])
plt.legend(["-X^2", "Horizzontal Line"])
plt.xlabel("X")
plt.ylabel("X squared")
# Out:
# <ipython-input-21-cb443e3987cd>:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1,2,1) # rows, columns, panel selected
# Text(0, 0.5, 'X squared')

# %% [markdown]
# ### **OOP Interface (better)**

# %%
fig, axes = plt.subplots(figsize=(12, 6))

# %%
axes.plot(
    x, (x**2), color = "red", linewidth=3,
    marker = "o", markersize=8, label="X^2")

axes.plot(
    x, -1 * (x**2),"b--", label="-X^2"
)
axes.set_xlabel("X")
axes.set_ylabel("Y")

axes.set_title("Grafico")
axes.legend()

fig

# %%
fix, axes = plt.subplots(figsize=(12,6))

axes.plot(x ,x + 0, linestyle = "solid")
axes.plot(x ,x + 1, linestyle = "dashed")
axes.plot(x ,x + 2, linestyle = "dashdot")
axes.plot(x ,x + 3, linestyle = "dotted")

axes.set_title("Grafo")
# Out:
# Text(0.5, 1.0, 'Grafo')

# %%
fix, axes = plt.subplots(figsize=(12,6))

axes.plot(x ,x + 0, "-og", label="solid green") #-og linea drita, o come marker e g di green
axes.plot(x ,x + 1, "--c", label="dashed cyan")
axes.plot(x ,x + 2, "-.b", label="dashdot blue")
axes.plot(x ,x + 3, ":c",  label="dotted red")

axes.legend()

axes.set_title("Grafo")
# Out:
# Text(0.5, 1.0, 'Grafo')

# %% [markdown]
# ### **Histograms**

# %%
values = np.random.randn(1000)

# %%
plt.subplots(figsize=(12,6))

plt.hist(values, bins = 100, alpha = 0.8,
         histtype = "bar", color = "steelblue",
         edgecolor = "green")
plt.xlim(xmin = -5, xmax = 5)
plt.show()

# %%
fig.savefig(nome.png)

# %% [markdown]
# ### **KDE (kernel destiny estimation)**

# %%
from scipy import stats

# %%
density = stats.kde.gaussian_kde(values)
density
# Out:
# <ipython-input-49-6857f6a4d934>:1: DeprecationWarning: Please use `gaussian_kde` from the `scipy.stats` namespace, the `scipy.stats.kde` namespace is deprecated.
#   density = stats.kde.gaussian_kde(values)

# %%
plt.subplots(figsize=(12,6))

values2 = np.linspace(min(values)-10, max(values)+10,100)

plt.plot(values2, density(values2),color="#FF7F00")
plt.fill_between(values2,0,density(values2), alpha=0.5, color="#FF7F00")
plt.xlim(xmin=-5,xmax=5)
plt.show()

# %% [markdown]
# ### **Combine plots**

# %%
plt.subplots(figsize=(12, 6))

plt.hist(values, bins=100, alpha=0.8, density=1,
          histtype='bar', color='steelblue',
          edgecolor='green')

plt.plot(values2, density(values2), color='#FF7F00', linewidth=3.0)
plt.xlim(xmin=-5, xmax=5)

plt.show()

# %% [markdown]
# ### **Bar plots**

# %%
Y = np.random.rand(1, 5)[0]
Y2 = np.random.rand(1, 5)[0]

# %%
plt.figure(figsize=(12, 4))

barWidth = 0.5
plt.bar(np.arange(len(Y)), Y, width=barWidth, color='#00b894')

plt.show()

# %%
plt.figure(figsize=(12, 4))

barWidth = 0.5
plt.bar(np.arange(len(Y)), Y, width=barWidth, color='#00b894', label='Label Y')
plt.bar(np.arange(len(Y2)), Y2, width=barWidth, color='#e17055', bottom=Y, label='Label Y2')

plt.legend()
plt.show()

# %% [markdown]
# ### **Boxplots and outlier detection**

# %%
values = np.concatenate([np.random.randn(10), np.array([10, 15, -10, -15])])

# %%
plt.figure(figsize=(12, 4))

plt.hist(values)
# Out:
# (array([1., 1., 0., 0., 4., 6., 0., 0., 1., 1.]),
#  array([-15., -12.,  -9.,  -6.,  -3.,   0.,   3.,   6.,   9.,  12.,  15.]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(12, 4))

plt.boxplot(values)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7a99f02e01f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7a99f02e1750>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7a99f0142dd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7a99f02e1c90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7a99f02e1f30>],
#  'means': []}
